# %%
import numpy as np
import networkx as nx
from gensim.models import KeyedVectors
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import pkuseg
import itertools
import logging
import gensim
from gensim.models import word2vec, KeyedVectors
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from chemdataextractor import Document
import pkuseg
from nltk.tokenize import MWETokenizer
import itertools
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
# 加载预训练的 Word2Vec 模型
model = KeyedVectors.load_word2vec_format('model.txt')

# %%
# 获取模型中的词汇表
vocab = model.index_to_key

# 随机选择1000个向量
selected_words = random.sample(vocab, k=1000)

# 打印选择的向量名
for word in selected_words:
    print(word)
# Out:
# said
# us
# understudied
# interconnect
# zones
# FiTs
# planting
# high-resolution
# emphasizes
# Mediterranean
# warranty
# approaches
# Serra
# 10−7
# spacers
# HABs
# citing
# 337
# pyrrolidinium
# Aqueous
# diagenesis
# viscoelastic
# imposed
# Tr
# supercapattery
# promoted
# micro-sized
# bulb
# pervasively
# dissociated
# CSD
# shutdown
# gullies
# wavy
# Intense
# Mountains
# WE
# expander
# P3HT-b-PS
# mid-Holocene
# government
# honeycombs
# hindered
# disconnected
# Swarm
# interdependencies
# PBT1-C
# SPVWP
# healthcare
# pertinent
# microbattery
# 943
# MC-Meso
# robustly
# timing
# MPEH
# official
# post-caldera
# witnessed
# purity
# compressible
# Room
# charts
# dispersions
# birnessite
# min
# reacted
# glare
# ammeter
# adjustment
# follow
# semi-insulating
# modal
# synthesis
# €
# H2
# seconds
# ions
# bimolecular
# rich
# organics
# sorption
# dm−3
# 880
# 0044
# cours
# d
# Sudan
# SiPM
# trioxide
# spreadsheet
# Staebler
# LB
# depression
# Balloon
# blast
# ...

# %%
# 使用TSNE进行降维
from sklearn.manifold import TSNE
# 获取选择的向量
selected_vectors = np.array([model.get_vector(word) for word in selected_words])

# 进行t-SNE降维
tsne = TSNE(n_components=2, random_state=42)
reduced_vectors = tsne.fit_transform(selected_vectors)

# %%
# 构建绘图数据
x = reduced_vectors[:, 0]
y = reduced_vectors[:, 1]

# 绘制散点图
plt.scatter(x, y, color='gray')

# 绘制高亮词汇的点
highlight_words = ['MAPbI3']
highlight_indices = [selected_words.index(word) for word in highlight_words]
highlight_color = 'blue'  # 更改为您想要的颜色

plt.scatter(x[highlight_indices], y[highlight_indices], color=highlight_color)

# 显示图形
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-653fe2776ee4> in <module>
#       8 # 绘制高亮词汇的点
#       9 highlight_words = ['MAPbI3']
# ---> 10 highlight_indices = [selected_words.index(word) for word in highlight_words]
#      11 highlight_color = 'blue'  # 更改为您想要的颜色
#      12
#
# <ipython-input-17-653fe2776ee4> in <listcomp>(.0)
#       8 # 绘制高亮词汇的点
#       9 highlight_words = ['MAPbI3']
# ---> 10 highlight_indices = [selected_words.index(word) for word in highlight_words]
#      11 highlight_color = 'blue'  # 更改为您想要的颜色
#      12
#
# ValueError: 'MAPbI3' is not in list
